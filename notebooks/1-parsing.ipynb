# %%
# %load_ext autoreload
# %autoreload 2

import sys; sys.path.append('../')
from pathlib import Path

from bike.util.parse import parse_qgis_data

# %%
vertices, edges = parse_qgis_data(
    Path('../data/qgis_data.csv'),
    delimiter=";",
    save_to_files=True,
    output=Path('../data/')
)
# Out:
# 100%|██████████| 11962/11962 [01:35<00:00, 124.95it/s]
